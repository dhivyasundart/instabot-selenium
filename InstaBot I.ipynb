# %%
# INSTABOT-I-

# %%
from selenium import webdriver
import pandas as pd
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup 
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
driver=webdriver.Chrome(executable_path='C:\\ChromeDriver\\chromedriver.exe')
wait=WebDriverWait(driver,10)

# %% [markdown]
# # Login to your Instagram Handle

# %%
driver.get('https://www.instagram.com/')
time.sleep(2)
login=driver.find_element_by_link_text('Log in')
login.click()
time.sleep(3)
#username=wait.until(EC.presence_of_element_located((By.XPATH,'//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input')))
#usm = username.send_keys("dhivyasundar98")
usm= driver.find_element_by_name('username').send_keys("instagram_username")
pwd = driver.find_element_by_name('password').send_keys("instagram_password")
btnLog = driver.find_element_by_tag_name('form').submit()
time.sleep(5)
wait.until(EC.element_to_be_clickable((By.XPATH, "//button[contains(.,'Not Now')]"))).click()

# %% [markdown]
# # Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”

# %%
search = wait.until(EC.presence_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.send_keys('food')
time.sleep(3)
foods=[]
fooditerator=driver.find_elements_by_xpath('//a[contains(@class,"yCE8d")]/div/div/div/span')
for i in fooditerator:
    name=i.get_attribute('innerHTML')
    if(name[0]!='#' and name[0]!='<'):
        foods.append(name)
foods
# Out:
# ['foodofchennai',
#  'foodtalkindia',
#  'foodozers',
#  'foodrush.recipe',
#  'foodnetwork',
#  'foodeatcapture',
#  'food',
#  'foodelicious_kw',
#  'chennaifoodtrails',
#  'dilsefoodie',
#  'foodtalk_chennai',
#  'madras__foodie',
#  'chennai_foodreviews',
#  'foodfeedtvm',
#  'foodys',
#  'foodaholic19',
#  'searchingsamayal_foodie',
#  'Food Consulate',
#  'Food Nirvana Egmore',
#  'Food Village',
#  'thisisinsiderfood',
#  'the.dining.chennai',
#  'food._.huntz',
#  'buzzfeedfood',
#  'foodiescutie',
#  'foodnetworkkitchen',
#  'foodofchefs',
#  'foodyfetish',
#  'mumbaifoodie',
#  'tinta_fooddiaries',
#  'foodcoimbatore',
#  'foodreviewskochi',
#  'foodhunter_sabu',
#  'icedtaster',
#  'foodfreq',
#  'village_food_factory_official',
#  'eatwithaksshay',
#  'foodiekuwait_']

# %% [markdown]
# # Open profile of “So Delhi”

# %%
search.clear()
search.send_keys('So Delhi')
time.sleep(1)
profiles=driver.find_elements_by_xpath('//a[contains(@class,"yCE8d")]/div/div[2]/span')
for i in profiles:
    if(i.get_attribute('innerHTML')=='So Delhi'):
        i.click()
        break

# %% [markdown]
# # Start following it. Print a message if you are already following

# %%
#fol=driver.find_element_by_xpath('//span[@class="vBF20 _1OSdk"]/button')
fol=wait.until(EC.element_to_be_clickable((By.XPATH,'//span[@class="vBF20 _1OSdk"]/button')))
if(fol.text == 'Following'):
    print("You are already following So Delhi")
else:
    fol.click()

# %% [markdown]
# # After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
if(fol.text=="Follow"):
    print("You are already not following So Delhi")
else:
    fol.click()
    unfol=driver.find_element_by_xpath('//div[@class="mt3GC"]/button')
    unfol.click()

# %% [markdown]
# # Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.

# %%
search = wait.until(EC.presence_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.clear()
search.send_keys('dilsefoodie')
profile=wait.until(EC.element_to_be_clickable((By.XPATH,'//a[contains(@class,"yCE8d")]')))
profile.click()
driver.execute_script('window.scrollBy(0,3000);')
time.sleep(3)
rows=driver.find_elements_by_xpath('//div[contains(@class,"v1Nh3 kIKUG  _bz0w")]')
for i in range(0,30):
    rows[i].click()
    like=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@class,"wpO6b ")]')))
    try:
        if(driver.find_element_by_xpath('//*[contains(@aria-label,"Unlike")]')):
            print("You have already liked post no." +str(i+1))        
    except NoSuchElementException:
        like.click()
    close=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@aria-label,"Close")]')))    
    #close=driver.find_element_by_xpath('//*[contains(@aria-label,"Close")]')
    close.click() 
    time.sleep(1)

# %% [markdown]
# # Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
rows=driver.find_elements_by_xpath('//div[contains(@class,"v1Nh3 kIKUG  _bz0w")]')
for i in range(0,30):
    rows[i].click()
    like=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@class,"wpO6b ")]')))
    try:
        if(driver.find_element_by_xpath('//*[contains(@aria-label,"Unlike")]')):
            like.click()                   
    except NoSuchElementException:
        print("You have already unliked post no."+str(i+1))        
    close=driver.find_element_by_xpath('//*[contains(@aria-label,"Close")]')
    close.click() 
    time.sleep(1)

# %% [markdown]
# # Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.

# %% [markdown]
# # (i)foodtalkindia

# %%
search = wait.until(EC.presence_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.clear()
search.send_keys('foodtalkindia')
profile=wait.until(EC.element_to_be_clickable((By.XPATH,'//a[contains(@class,"yCE8d")]')))
profile.click()
time.sleep(2)
#followers_panel1=wait.until(EC.element_to_be_clickable((By.XPATH,"//a[starts-with(@class,'sqdOP yWX7d    y3zKF    ZIAjV ')]")))
#followers_panel1.click()
followerlist=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a')))
followerlist.click()
time.sleep(3)
count=500
i=0
li=[]
followers_panel = driver.find_element_by_xpath('//div[@class = "isgrP"]')
current_scroll_position, new_height= 0, 1
while(i<500):
    try:           
        follower = driver.find_elements_by_class_name('_0imsa ')
    
        li.append(follower[i].text) #append the text of webelement to list
        print("User "+str(i+1)+" : "+follower[i].text)
        i += 1
    except IndexError:
        speed = 0.5
        current_scroll_position = new_height
        new_height = driver.execute_script("return arguments[0].scrollHeight",followers_panel)
        while current_scroll_position <= new_height:
            current_scroll_position += speed
            driver.execute_script("arguments[0].scrollTo(0, arguments[1]);",followers_panel,current_scroll_position)
        time.sleep(2)
wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@aria-label,"Close")]'))).click()         
#li has the 500 followers
# Out:
# User 1 : vkabugade
# User 2 : foodoverzindagi
# User 3 : richasaraswat1103
# User 4 : independentsoul_sachi
# User 5 : ish_sokhi
# User 6 : ruuu786
# User 7 : cutejazz_8455
# User 8 : soulnutnutribar
# User 9 : ankush.bhardwajj
# User 10 : itsjustsingh
# User 11 : darshil_3.3
# User 12 : rashmi.gahlaut_310
# User 13 : aditi_dikhit_
# User 14 : socorroglobalcuisine
# User 15 : official_badal_21217
# User 16 : md.akram.0333
# User 17 : mua_surabhikundra
# User 18 : thedreampalate
# User 19 : ashwani891
# User 20 : zaffar.ne
# User 21 : thesecretconsultant
# User 22 : siyafashionnstyle
# User 23 : missalreja
# User 24 : designofinteriors_indore
# User 25 : mr.shahrozali
# User 26 : javedpathan4562
# User 27 : le_dakaar
# User 28 : rachyitaahuja
# User 29 : palvinder7501
# User 30 : paratha.inn
# User 31 : tarannum3208
# User 32 : naruto_in_town
# User 33 : an_kush10
# User 34 : gopika5245
# User 35 : jay.pandya._
# User 36 : neeraj_mahour_
# User 37 : yash.sureka
# ...

# %% [markdown]
# # (ii)sodelhi

# %%
search = wait.until(EC.presence_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.clear()
search.send_keys('sodelhi')
profile=wait.until(EC.element_to_be_clickable((By.XPATH,'//a[contains(@class,"yCE8d")]')))
profile.click()
time.sleep(2)
followerlist=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a')))
followerlist.click()
time.sleep(3)
count=500
i=0
li2=[]
followers_panel = driver.find_element_by_xpath('//div[@class = "isgrP"]')
current_scroll_position, new_height= 0, 1
while(i<500):
    try:           
        follower = driver.find_elements_by_class_name('_0imsa ')
    
        li2.append(follower[i].text) #append the text of webelement to list
        print("User "+str(i+1)+" : "+follower[i].text)
        i += 1
    except IndexError:
        speed = 0.5
        current_scroll_position = new_height
        new_height = driver.execute_script("return arguments[0].scrollHeight",followers_panel)
        while current_scroll_position <= new_height:
            current_scroll_position += speed
            driver.execute_script("arguments[0].scrollTo(0, arguments[1]);",followers_panel,current_scroll_position)
        time.sleep(2)
wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@aria-label,"Close")]'))).click()        
#li2 has sodelhi followers
# Out:
# User 1 : adityagulati_
# User 2 : creative_me_____
# User 3 : avirathor
# User 4 : khushii._.15
# User 5 : parag16sep
# User 6 : ashishwilliam
# User 7 : kittu_gujjar11
# User 8 : varun_ahuja95
# User 9 : 7priyankayadav
# User 10 : foodoverzindagi
# User 11 : aakanshasrivastava26
# User 12 : yogitavishalmangukiya
# User 13 : ravikiran_30
# User 14 : cool_shadab.s1207
# User 15 : charudayal
# User 16 : mohsinkhasherwani
# User 17 : jesusawyoutwerking
# User 18 : _adamantleo23
# User 19 : bakethroughme
# User 20 : vaishnavisomani
# User 21 : nishtha1809
# User 22 : i_am_vaib
# User 23 : preet.loveofficial
# User 24 : falashwal
# User 25 : anshu_upasak
# User 26 : akash__namdev___
# User 27 : kundan.nayak.5076
# User 28 : fashionup____
# User 29 : jahnvichadha
# User 30 : l.neha.gulati.l
# User 31 : hemdutt_verma
# User 32 : aayush__gupta___
# User 33 : nature_food_travel_photography
# User 34 : preeti_bhanot19
# User 35 : vishaljaiswal4823
# User 36 : udayraj.singh.77920526
# ...

# %% [markdown]
# # Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %% [markdown]
# # i)get list of my followers

# %%
wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@aria-label,"Profile")]'))).click()
time.sleep(2)
num_of_followers1=wait.until(EC.element_to_be_clickable((By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a/span')))
num_of_followers=(int(num_of_followers1.text))
time.sleep(2)
num_of_followers1.click()
time.sleep(3)
myfollowers=[]
i=0
followers_panel = driver.find_element_by_xpath('//div[@class = "isgrP"]')
current_scroll_position, new_height= 0, 1
while(i< num_of_followers):
    try:           
        follower = driver.find_elements_by_class_name('_0imsa ')    
        myfollowers.append(follower[i].text) #append the text of webelement to list
        #print(follower[i].text)
        i += 1
        if(i==num_of_followers-1):
            break
    except IndexError:
        speed = 5
        current_scroll_position = new_height
        new_height = driver.execute_script("return arguments[0].scrollHeight",followers_panel)
        
        while current_scroll_position <= new_height:
            current_scroll_position += speed
            driver.execute_script("arguments[0].scrollTo(0, arguments[1]);",followers_panel,current_scroll_position)
        time.sleep(2)
wait.until(EC.element_to_be_clickable((By.XPATH,'html/body/div[4]/div/div[1]/div/div[2]/button/svg'))).click()        
myfollowers
# Out:
# ['_check_mee_out_',
#  'bakedmajesty_97',
#  'keexxh',
#  'nev_ishere',
#  'bhaktinandha',
#  'being_mayurrr',
#  'shweta_sj1224',
#  'ishitabaranwal',
#  'div_mathew_',
#  'chummi_jee',
#  'eshuuu_99',
#  'laay_patel',
#  'joe_mysteryboi',
#  'srujanasreemondi',
#  'melwin_perfect',
#  'magilansaravanan',
#  'samuel2983',
#  'blaze_black_leo',
#  'priya.sak79',
#  '_georgiethat_',
#  'iramziinya',
#  'itharakan_',
#  'raz_ana_sha_bri',
#  'manasi.khamkar',
#  'krishna.io',
#  'akash.hanumante',
#  'chin_by_cot',
#  'amit_hypnosis',
#  'mru_1710',
#  'harshita_phalor',
#  'n.a.u.s.h.a.d_',
#  '_ranyan',
#  'jobdavidd___',
#  'shreyajannet',
#  'guruckeeran',
#  'aravind_ramesh28',
#  'haz_chiquitita',
#  'thispersongetstheweirdestname',
#  'tonyydsa98',
#  'zoya_nm',
#  'adari.girishkumar',
#  'skatty_ks',
#  'dreamerofalostworld',
#  'sajida_jain',
#  'bhavyaarava',
#  'rafialshaikh',
#  'manns55',
#  'christlovejoel',
#  'mohammed____reda',
#  '_abdulmuqeet_',
#  'dalemachado',
# ...

# %% [markdown]
# # ii)followers of “foodtalkindia” that you are following but those who don’t follow you - considering first 500 followers only (including mutual and non-mutual)

# %%
mutual=[]
i=0
ind=0
current_scroll_position, new_height= 0, 1
search = wait.until(EC.presence_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.clear()
search.send_keys('foodtalkindia')
profile=wait.until(EC.element_to_be_clickable((By.XPATH,'//a[contains(@class,"yCE8d")]')))
profile.click()
time.sleep(2)
#followers_panel = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a/span').click()
wait.until(EC.element_to_be_clickable((By.XPATH,"//span[contains(@class,'tc8A9')]"))).click()
followers_panel1=wait.until(EC.element_to_be_clickable((By.XPATH,"//a[starts-with(@class,'sqdOP yWX7d    y3zKF    ZIAjV ')]")))
followers_panel1.click()
followers_panel = driver.find_element_by_xpath('//div[@class = "isgrP"]')
time.sleep(2)
while(True):
    try:
        if(i==500):
            break
         
        follower = driver.find_elements_by_class_name('_0imsa ')
        state=driver.find_element_by_xpath('html/body/div[4]/div/div[2]/ul/div/li['+str(i+1)+']/div/div[2]/button').text
        if(state=="Follow"):
            i=i+1
        else:
            mutual.append(follower[i].text) #append the userid list
            i=i+1
        
    except NoSuchElementException:
        speed = 5
        current_scroll_position = new_height
        new_height = driver.execute_script("return arguments[0].scrollHeight",followers_panel)
        
        while current_scroll_position <= new_height:
            current_scroll_position += speed
            driver.execute_script("arguments[0].scrollTo(0, arguments[1]);",followers_panel,current_scroll_position)
        time.sleep(2)
wait.until(EC.element_to_be_clickable((By.XPATH,'//*[contains(@aria-label,"Close")]'))).click()
a=False
for i in mutual:
    if(i in myfollowers) is False:
        a=True
        print(i)  
if(a==False):
    print("There is no one you follow who follows the handle, where they dont follow you back")
# Out:
# foodgems.pune
# clickalmost
# inayummyparadise
# mostlysane

# %% [markdown]
# # Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
# If You have already seen the story.
# Or The user has no story.
# Or View the story if not yet seen.

# %%
search = wait.until(EC.visibility_of_element_located((By.XPATH, "//input[contains(@class,'XTCLo')]")))
search.clear()
search.send_keys('coding.ninjas')
profile=wait.until(EC.element_to_be_clickable((By.XPATH,'//a[contains(@class,"yCE8d")]')))
profile.click()
try:
    story=wait.until(EC.element_to_be_clickable((By.XPATH,'//div[contains(@class,"RR-M- h5uC0")]')))
    w=driver.find_element_by_xpath('//div[contains(@class,"RR-M- h5uC0")]/canvas').get_attribute('width')
    if(w=='87'):
        print('Already viewed story')
    else:
        print('Story not yet seen so viewing it now')    
        story.click()
        
except TimeoutException:
    print("User has no story")
# Out:
# User has no story
